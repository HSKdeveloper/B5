# %% [markdown]
# Name : Hissah Alkharboush

# %% [markdown]
# # M1.Ex1: Model Hours vs Marks

# %% [markdown]
# - Run: [**Open In Colab**](https://colab.research.google.com/github/HassanAlgoz/B5/blob/main/content/W3/M1/exercises/ex1_reg.ipynb)
# - Raw Dataset: [Rounded_Student_Hours_Studied_vs_Marks_Dataset.csv](https://raw.githubusercontent.com/HassanAlgoz/B5/main/content/datasets/Rounded_Student_Hours_Studied_vs_Marks_Dataset.csv)

# %%
import pandas as pd
from sklearn.datasets import fetch_openml

# %% [markdown]
# ### Step 1. Load the data

# %%
model_df = pd.read_csv("https://raw.githubusercontent.com/HassanAlgoz/B5/main/content/datasets/Rounded_Student_Hours_Studied_vs_Marks_Dataset.csv")

# %%
model_df.head()
# Out:
#    Hours_Studied  Marks
# 0           4.76  46.27
# 1           3.00  34.30
# 2           2.08  33.63
# 3           4.04  47.81
# 4           9.49  66.26

# %% [markdown]
# ### Step 2.a Assign variables `X` to the features and `y` to the target

# %%
X = model_df[['Hours_Studied']]
y = model_df['Marks']

# %% [markdown]
# ### Step 2.b print the type of each

# %%
X.dtypes
# Out:
# Hours_Studied    float64
# dtype: object

# %%
y.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 2.c identify whether the target is categorical or numerical & whether the task is regression or classification

# %% [markdown]
# The target is numerical
# The task is regression

# %% [markdown]
# ### Step 3. Identify the number of samples and columns of both the data matrix and the target

# %%
X.shape
# Out:
# (100, 1)

# %%
y.shape
# Out:
# (100,)

# %% [markdown]
# ### Step 4. Summarize the distribution of the data (min, max, median, mean, and standard deviation)

# %%
model_df.describe()
# Out:
#        Hours_Studied       Marks
# count     100.000000  100.000000
# mean        5.376300   46.360200
# std         2.593013   14.284805
# min         1.050000   20.190000
# 25%         3.175000   33.675000
# 50%         5.565000   47.485000
# 75%         7.255000   57.377500
# max         9.870000   73.260000

# %% [markdown]
# ### Step 5. Plot the feature vs the target

# %%
import seaborn as sns

sns.scatterplot(model_df, x='Hours_Studied', y='Marks')
# Out:
# <Axes: xlabel='Hours_Studied', ylabel='Marks'>

# %% [markdown]
# ### Step 6. What is the relationship between the feature and the target? (increasing or decreasing or none)

# %% [markdown]
# Increasing

# %% [markdown]
# ### Step 7. Initialize a `LinearRegression` model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %% [markdown]
# ### Step 8. Split the dataset into train and test sets

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=10,
)

# %% [markdown]
# ### Step 9.a Train the model on the training set

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Step 9.b Identify the learned slope and the y-intercept of the model

# %%
m = model.coef_[0].round(2)
b = model.intercept_.round(2)

# %%
print('slope:', m)
print('intercept:', b)
# Out:
# slope: 5.09
# intercept: 19.58

# %% [markdown]
# ### Step 9.c how much marks do we get per 1 hour of study?

# %%
print("We get", m, "marks per 1 hour of study")
# Out:
# We get 5.09 marks per 1 hour of study

# %% [markdown]
# ### Step 9.d how much does a 10 minutes increase of study time adds to our marks?

# %%
how_much = (1 / 6) * m
how_much.round(2)
# Out:
# np.float64(0.85)

# %% [markdown]
# ### Step 9.e if one doesn't study at all, how much marks do they get?

# %%
print("If one doesn't study at all, they get", b, "marks")
# Out:
# If one doesn't study at all, they get 19.58 marks

# %% [markdown]
# ### Step 10. Evaluate the model on the test set

# %%
model.score(X_test, y_test)
# Out:
# 0.8149405607914277

# %% [markdown]
# ### Step 11. Take a sample of three rows from the test set and make a prediction on them and check whether they match the true label or not

# %%
idx = X_test.sample(3).index

X_sample = X_test.loc[idx]
y_sample = y_test.loc[idx]

y_pred = model.predict(X_test.loc[idx])

# %%
pd.DataFrame({
    'y_pred': y_pred,
    'y_true': y_test.loc[idx]
})
# Out:
#        y_pred  y_true
# 68  65.252517   66.73
# 41  25.429426   26.60
# 2   30.159371   33.63

# %% [markdown]
# ### Step 12. Plot the data and the regression line

# %%
range(0, 10, 1)
# Out:
# range(0, 10)

# %%
import numpy as np

x_range = np.linspace(X.min(), X.max(), num=100)

# %%
model.predict(x_range)
# Out:
# c:\Users\96654\Desktop\2026\SDAIA-Bootcamp\B5\content\W2\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([24.92082938, 25.37394246, 25.82705554, 26.28016862, 26.7332817 ,
#        27.18639479, 27.63950787, 28.09262095, 28.54573403, 28.99884711,
#        29.45196019, 29.90507328, 30.35818636, 30.81129944, 31.26441252,
#        31.7175256 , 32.17063869, 32.62375177, 33.07686485, 33.52997793,
#        33.98309101, 34.43620409, 34.88931718, 35.34243026, 35.79554334,
#        36.24865642, 36.7017695 , 37.15488258, 37.60799567, 38.06110875,
#        38.51422183, 38.96733491, 39.42044799, 39.87356107, 40.32667416,
#        40.77978724, 41.23290032, 41.6860134 , 42.13912648, 42.59223957,
#        43.04535265, 43.49846573, 43.95157881, 44.40469189, 44.85780497,
#        45.31091806, 45.76403114, 46.21714422, 46.6702573 , 47.12337038,
#        47.57648346, 48.02959655, 48.48270963, 48.93582271, 49.38893579,
#        49.84204887, 50.29516195, 50.74827504, 51.20138812, 51.6545012 ,
#        52.10761428, 52.56072736, 53.01384045, 53.46695353, 53.92006661,
#        54.37317969, 54.82629277, 55.27940585, 55.73251894, 56.18563202,
#        56.6387451 , 57.09185818, 57.54497126, 57.99808434, 58.45119743,
#        58.90431051, 59.35742359, 59.81053667, 60.26364975, 60.71676283,
#        61.16987592, 61.622989  , 62.07610208, 62.52921516, 62.98232824,
#        63.43544133, 63.88855441, 64.34166749, 64.79478057, 65.24789365,
#        65.70100673, 66.15411982, 66.6072329 , 67.06034598, 67.51345906,
#        67.96657214, 68.41968522, 68.87279831, 69.32591139, 69.77902447])

# %%
import matplotlib.pyplot as plt

plt.plot(x_range, model.predict(x_range), color='red')
plt.scatter(X, y)
# Out:
# c:\Users\96654\Desktop\2026\SDAIA-Bootcamp\B5\content\W2\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

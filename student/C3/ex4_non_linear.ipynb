# %% [markdown]
# Name : Hissah Alkharboush

# %% [markdown]
# # M1.Ex4: Modeling Non-linear Patterns

# %% [markdown]
# - Run: [**Open In Colab**](https://colab.research.google.com/github/HassanAlgoz/B5/blob/main/content/W3/M1/exercises/ex4_non-linear.ipynb)
# - Raw Dataset: [bmi_and_life_expectancy.csv](https://raw.githubusercontent.com/HassanAlgoz/B5/main/content/datasets/bmi_and_life_expectancy.csv)

# %%
import pandas as pd
import sklearn

# %% [markdown]
# ### Step 1. Load the data

# %%
data = "https://raw.githubusercontent.com/HassanAlgoz/B5/main/content/datasets/bmi_and_life_expectancy.csv"

# %%
df_model = pd.read_csv(data)
df_model.head()
# Out:
#        Country  Life expectancy       BMI
# 0  Afghanistan             52.8  20.62058
# 1      Albania             76.8  26.44657
# 2      Algeria             75.5  24.59620
# 3      Andorra             84.6  27.63048
# 4       Angola             56.7  22.25083

# %% [markdown]
# ### Step 2.a Assign variables `X` to the features and `y` to the target

# %%
x = df_model[['Life expectancy']]
y = df_model['BMI']

# %% [markdown]
# ### Step 2.b print the type of each

# %%
x.dtypes
# Out:
# Life expectancy    float64
# dtype: object

# %%
y.dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 2.c identify whether the target is categorical or numerical & whether the task is regression or classification

# %% [markdown]
# - Categorical target
# - So: classification task

# %% [markdown]
# ### Step 3. Identify the number of samples and columns of both the data matrix and the target

# %%
x.shape
# Out:
# (163, 1)

# %%
y.shape
# Out:
# (163,)

# %% [markdown]
# ### Step 4. Summarize the distribution of the data (min, max, median, mean, and standard deviation)

# %%
x.describe()
# Out:
#        Life expectancy
# count       163.000000
# mean         69.666933
# std           8.981933
# min          44.500000
# 25%          63.450000
# 50%          71.800000
# 75%          76.500000
# max          84.600000

# %%
y.describe()
# Out:
# count    163.000000
# mean      24.792378
# std        2.427900
# min       19.866920
# 25%       22.527940
# 50%       25.320540
# 75%       26.603960
# max       30.995630
# Name: BMI, dtype: float64

# %% [markdown]
# ### Step 5. Plot the feature vs the target

# %%
full_df = pd.concat([x, y], axis=1)
full_df
# Out:
#      Life expectancy       BMI
# 0               52.8  20.62058
# 1               76.8  26.44657
# 2               75.5  24.59620
# 3               84.6  27.63048
# 4               56.7  22.25083
# ..               ...       ...
# 158             63.4  26.78926
# 159             74.1  26.57750
# 160             74.1  20.91630
# 161             51.1  20.68321
# 162             47.3  22.02660
#
# [163 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(1, 2, figsize=(10, 5))

sns.scatterplot(
    data=full_df,
    x='	Life expectancy',
    y='BMI',
    hue='target',
    ax=ax[0]
)
sns.scatterplot(
    data=full_df,
    x='petal length (cm)',
    y='petal width (cm)',
    hue='target',
    ax=ax[1]
)

fig.suptitle("Life expectancy and BMI")

ax[0].set_title("Life expectancy")
ax[1].set_title("BMI")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 6
#       2 import seaborn as sns
#       4 fig, ax = plt.subplots(1, 2, figsize=(10, 5))
# ----> 6 sns.scatterplot(
#       7     data=full_df,
#       8     x='	Life expectancy',
#       9     y='BMI',
#      10     hue='target',
#      11     ax=ax[0]
#      12 )
#      13 sns.scatterplot(
#      14     data=full_df,
#      15     x='petal length (cm)',
#    (...)     18     ax=ax[1]
#      19 )
#      21 fig.suptitle("Life expectancy and BMI")
#
# File c:\Users\96654\Desktop\2026\SDAIA-Bootcamp\B5\content\W2\.venv\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)    612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File c:\Users\96654\Desktop\2026\SDAIA-Bootcamp\B5\content\W2\.venv\Lib\site-packages\seaborn\relational.py:396, in _ScatterPlotter.__init__(self, data, variables, legend)
#     387 def __init__(self, *, data=None, variables={}, legend=None):
#     388
#     389     # TODO this is messy, we want the mapping to be agnostic about
#     390     # the kind of plot to draw, but for the time being we need to set
#     391     # this information so the SizeMapping can use it
#     392     self._default_size_range = (
#     393         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     394     )
# --> 396     super().__init__(data=data, variables=variables)
#     398     self.legend = legend
#
# File c:\Users\96654\Desktop\2026\SDAIA-Bootcamp\B5\content\W2\.venv\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File c:\Users\96654\Desktop\2026\SDAIA-Bootcamp\B5\content\W2\.venv\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File c:\Users\96654\Desktop\2026\SDAIA-Bootcamp\B5\content\W2\.venv\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File c:\Users\96654\Desktop\2026\SDAIA-Bootcamp\B5\content\W2\.venv\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `	Life expectancy` for `x`. An entry with this name does not appear in `data`.

# %% [markdown]
# ### Step 6. What is the relationship between the feature and the target? (increasing or decreasing or none)

# %% [markdown]
# ### Step 7. Make two modeling techniques
#
# First model is just a Linear Regression model: `from sklearn.linear_model import LinearRegression`
#
# Second model: Use one of the previously mentioned methods to model a non-linear relationship
#
# 1. `from sklearn.tree import DecisionTreeRegressor`
# 2. or `from sklearn.preprocessing import PolynomialFeatures`

# %% [markdown]
# ### Step 8. Split the dataset into train and test sets

# %% [markdown]
# ### Step 9. Train both models on the training set

# %% [markdown]
# ### Step 10. Evaluate and compare which of the two models score better on the `train` set

# %% [markdown]
# ### Step 11. Evaluate and compare which of the two models score better on the `test` set
